# %% [markdown]
# # ExtratorDeConteudoDaNasa:

# %%
import pandas as pd
import json
import requests
from io import BytesIO
from PIL import Image, ImageFont, ImageDraw
import imageio
import os

# %%
url = requests.get("http://127.0.0.1:8000/linguagens/?format=json")

# %%
dicionario_de_filmes = json.loads(url.content)
dicionario_de_filmes
# Out:
# [{'id': 1,
#   'title': 'Python',
#   'url': 'https://raw.githubusercontent.com/abrahamcalf/programming-languages-logos/master/src/python/python_256x256.png',
#   'ranking': 1},
#  {'id': 2,
#   'title': 'Java',
#   'url': 'https://raw.githubusercontent.com/abrahamcalf/programming-languages-logos/master/src/java/java_256x256.png',
#   'ranking': 3},
#  {'id': 3,
#   'title': 'JavaScript',
#   'url': 'https://raw.githubusercontent.com/abrahamcalf/programming-languages-logos/master/src/javascript/javascript_256x256.png',
#   'ranking': 6},
#  {'id': 4,
#   'title': 'Kotlin',
#   'url': 'https://raw.githubusercontent.com/abrahamcalf/programming-languages-logos/master/src/kotlin/kotlin_256x256.png',
#   'ranking': 4},
#  {'id': 6,
#   'title': 'PHP',
#   'url': 'https://raw.githubusercontent.com/abrahamcalf/programming-languages-logos/master/src/php/php_256x256.png',
#   'ranking': 8},
#  {'id': 7,
#   'title': 'C',
# ...

# %%
conteudos = []
for url in dicionario_de_filmes:
    conteudos = url.get('title')
    conteudos = url.get('url')

# %%
diretorio = input('nome do diretório: ')

os.makedirs(diretorio)

for url in dicionario_de_filmes:
    print(url.get('title'))
    response = requests.get(url.get('url'))
    imagem = Image.open(BytesIO(response.content))
    draw = ImageDraw.Draw(imagem)
    font = ImageFont.truetype("Uchen-Regular.ttf", 80)
    draw.text((20, 25), "Hello World!", font=font)

    titulo_imagem = f"{url.get('title')}.png"

    imageio.imwrite(f"{diretorio}/{titulo_imagem}", imagem)
# Out:
# Find the Man in the Moon
# M51: The Whirlpool Galaxy from Hubble
# Satellites Behind Pinnacles

# %% [markdown]
# # ExtratorDeConteudoDoImdb

# %%
url = requests.get("https://mocki.io/v1/9a7c1ca9-29b4-4eb3-8306-1adb9d159060")

# %%
dicionario_de_filmes = json.loads(url.content)

# %%
lista_de_filmes = dicionario_de_filmes["items"]

# %%
for url in lista_de_filmes:
    print(url.get('title'))
    print(url.get('image'))
# Out:
# The Shawshank Redemption
# https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX128_CR0,3,128,176_AL_.jpg
# The Godfather
# https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX128_CR0,1,128,176_AL_.jpg
# The Dark Knight
# https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX128_CR0,3,128,176_AL_.jpg
# The Godfather: Part II
# https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX128_CR0,1,128,176_AL_.jpg
# 12 Angry Men
# https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX128_CR0,3,128,176_AL_.jpg
# Schindler's List
# https://m.media-amazon.com/images/M/MV5BNDE4OTMxMTctNmRhYy00NWE2LTg3YzItYTk3M2UwOTU5Njg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX128_CR0,3,128,176_AL_.jpg
# ...

# %%
diretorio = input('nome do diretório: ')

os.makedirs(diretorio)

for url in lista_de_filmes:
    print(url.get('title'))
    response = requests.get(url.get('image'))
    imagem = Image.open(BytesIO(response.content))
    draw = ImageDraw.Draw(imagem)
    font = ImageFont.truetype("Uchen-Regular.ttf", 80)
    draw.text((20, 25), "Hello World!", font=font)

    titulo_imagem = f"{url.get('title')}.png"

    imageio.imwrite(f"{diretorio}/{titulo_imagem}", imagem)
# Out:
# The Shawshank Redemption
# The Godfather
# The Dark Knight
# The Godfather: Part II
# 12 Angry Men
# Schindler's List
# The Lord of the Rings: The Return of the King
# Pulp Fiction
# The Lord of the Rings: The Fellowship of the Ring
# The Good, the Bad and the Ugly
# Forrest Gump
# Fight Club
# Inception
# The Lord of the Rings: The Two Towers
# Star Wars: Episode V - The Empire Strikes Back
# The Matrix
# Goodfellas
# One Flew Over the Cuckoo's Nest
# Se7en
# Seven Samurai
# It's a Wonderful Life
# The Silence of the Lambs
# City of God
# Saving Private Ryan
# Life Is Beautiful
# The Green Mile
# Star Wars
# Interstellar
# Terminator 2: Judgment Day
# Back to the Future
# Spirited Away
# Psycho
# The Pianist
# Léon: The Professional
# Parasite
# The Lion King
# Gladiator
# American History X
# The Usual Suspects
# The Departed
# The Prestige
# Casablanca
# Whiplash
# The Intouchables
# Modern Times
# Hara-Kiri
# Once Upon a Time in the West
# Grave of the Fireflies
# Rear Window
# ...

# %%
import django_heroku
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_86199/192388510.py in <module>
# ----> 1 import django_heroku
#
# ModuleNotFoundError: No module named 'django_heroku'

# %%
import secrets

# %%
secrets.token_hex(24)
# Out:
# '744238f39326993bdcaeb6b37589087d938066d5d43bba30'
